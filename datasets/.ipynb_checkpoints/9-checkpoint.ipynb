# %% [markdown]
#     # Automatic Jupyter Notebook for OpenML dataset 9: autos

# %%
# %matplotlib inline
from scripts.preamble import *
import warnings
warnings.filterwarnings('ignore')
did = 9
data = oml.datasets.get_dataset(did)
X, y, features = getData(data)
task, topList, strats, scores = getOpenMLData(did, data.default_target_attribute) 
topList[:10]
# Out:
#                                                 flow     score
# 0  weka.kf.AttributeSelection-Ranker-ReliefF-KSta...  0.972876
# 1    weka.RotationForest_PrincipalComponents_J48(14)  0.971229
# 2     weka.RotationForest_PrincipalComponents_J48(3)  0.970180
# 3    weka.RotationForest_PrincipalComponents_J48(14)  0.970180
# 4  weka.kf.AttributeSelection-BestFirst-CfsSubset...  0.967469
# 5    weka.RotationForest_PrincipalComponents_J48(14)  0.967256
# 6    weka.RotationForest_PrincipalComponents_J48(14)  0.966511
# 7                                weka.Bagging_J48(2)  0.964775
# 8                                weka.Bagging_J48(1)  0.964775
# 9  sklearn.pipeline.Pipeline(imputer=sklearn.impu...  0.963610

# %%
from scripts.problemType import *
problemType = findProblemType(data) 
checkTask(task, problemType, data.default_target_attribute)
# Out:
# Problem type: supervised classification problem.
# Using correct task

# %%
from scripts.dataVisualization import *
show1DHist(data)

# %%
from scripts.outlierDetection import *
outlierDetection(X, features, 10) 
plt.savefig('styled-dataframe.svg')
# Out:
# <style  type="text/css" >
#     #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow0_col2 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow0_col4 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow0_col6 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow0_col13 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow0_col16 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow0_col25 {
#             background-color:  #ff0000;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow1_col2 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow1_col4 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow1_col6 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow1_col13 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow1_col16 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow1_col17 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow1_col25 {
#             background-color:  #ff1f1f;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow2_col2 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow2_col6 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow2_col13 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow2_col16 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow2_col17 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow2_col25 {
#             background-color:  #ff2c2c;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow3_col3 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow3_col6 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow3_col19 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow3_col25 {
#             background-color:  #ff4b4b;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow4_col3 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow4_col4 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow4_col6 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow4_col19 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow4_col25 {
#             background-color:  #ffa9a9;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow5_col2 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow5_col4 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow5_col25 {
#             background-color:  #ffb8b8;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow6_col2 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow6_col6 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow6_col12 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow6_col16 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow6_col18 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow6_col25 {
#             background-color:  #ffd8d8;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow7_col2 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow7_col6 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow7_col12 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow7_col16 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow7_col18 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow7_col25 {
#             background-color:  #ffdcdc;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow8_col3 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow8_col6 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow8_col19 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow8_col25 {
#             background-color:  #ffe3e3;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow9_col2 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow9_col4 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow9_col6 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow9_col16 {
#             background-color:  yellow;
#         }    #T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow9_col25 {
#             background-color:  #ffe5e5;
#         }</style>
# <table id="T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcf" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >normalized-losses</th>
#         <th class="col_heading level0 col1" >make</th>
#         <th class="col_heading level0 col2" >fuel-type</th>
#         <th class="col_heading level0 col3" >aspiration</th>
#         <th class="col_heading level0 col4" >num-of-doors</th>
#         <th class="col_heading level0 col5" >body-style</th>
#         <th class="col_heading level0 col6" >drive-wheels</th>
#         <th class="col_heading level0 col7" >engine-location</th>
#         <th class="col_heading level0 col8" >wheel-base</th>
#         <th class="col_heading level0 col9" >length</th>
#         <th class="col_heading level0 col10" >width</th>
#         <th class="col_heading level0 col11" >height</th>
#         <th class="col_heading level0 col12" >curb-weight</th>
#         <th class="col_heading level0 col13" >engine-type</th>
#         <th class="col_heading level0 col14" >num-of-cylinders</th>
#         <th class="col_heading level0 col15" >engine-size</th>
#         <th class="col_heading level0 col16" >fuel-system</th>
#         <th class="col_heading level0 col17" >bore</th>
#         <th class="col_heading level0 col18" >stroke</th>
#         <th class="col_heading level0 col19" >compression-ratio</th>
#         <th class="col_heading level0 col20" >horsepower</th>
#         <th class="col_heading level0 col21" >peak-rpm</th>
#         <th class="col_heading level0 col22" >city-mpg</th>
#         <th class="col_heading level0 col23" >highway-mpg</th>
#         <th class="col_heading level0 col24" >price</th>
#         <th class="col_heading level0 col25" >outlier</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcflevel0_row0" class="row_heading level0 row0" >49</th>
#         <td id="T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow0_col0" class="data row0 col0" >nan</td>
#         <td id="T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow0_col1" class="data row0 col1" >7</td>
#         <td id="T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow0_col2" class="data row0 col2" >1</td>
#         <td id="T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow0_col3" class="data row0 col3" >0</td>
#         <td id="T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow0_col4" class="data row0 col4" >1</td>
#         <td id="T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow0_col5" class="data row0 col5" >2</td>
#         <td id="T_1783eeac_5a01_11e9_aeaf_6245b4ebbdcfrow0_col6" class="data row0 col6" >2</td>
#         <td

# %%
from scripts.localDataOpenMLInterface import *
showTopNSimilarDatasets("datasetSimilarityMatrixNormalized", did, 10)
# Out:
#     did                       name  similarity                            url
# 0   328                    bridges       0.717   https://www.openml.org/d/328
# 1   171              primary-tumor       0.672   https://www.openml.org/d/171
# 2   372             internet_usage       0.633   https://www.openml.org/d/372
# 3  1459      artificial-characters       0.622  https://www.openml.org/d/1459
# 4    41                      glass       0.620    https://www.openml.org/d/41
# 5   184                      kropt       0.620   https://www.openml.org/d/184
# 6   327                    bridges       0.614   https://www.openml.org/d/327
# 7   382          ipums_la_97-small       0.614   https://www.openml.org/d/382
# 8   133  BNG(glass,nominal,137781)       0.604   https://www.openml.org/d/133
# 9   307                      vowel       0.584   https://www.openml.org/d/307

# %% [markdown]
# Complexity threshold to determine if an algorithm will be run.

# %%
comp = 50000000000000

# %%
from scripts.featureImportance import *
featureImportance(data)

# %%
from scripts.baselines import *
maxBaseline = generateBaselines(data, problemType)

# %% [markdown]
# Please run the full notebook then toggle removeOutliers and run this cell and the next to compare the algorithms with and without outliers.

# %%
removeOutliers = True

# %%
from scripts.machineLearningAlgorithms import *
settings = runMachineLearningAlgorithms(data, comp, strats, problemType, task, showRuntimePrediction=True, runTPOT=False, removeOutliers=removeOutliers)
plot_alg(data, settings.strats, maxBaseline, problemType)
# Out:
# c:\users\hugo\anaconda3\lib\site-packages\deap\tools\_hypervolume\pyhv.py:33: ImportWarning: Falling back to the python version of hypervolume module. Expect this to be very slow.
#   "module. Expect this to be very slow.", ImportWarning)
# J48 Median execution time in ms: 10.0
# J48 Mean execution time in ms: 480.0
# NaiveBayes Median execution time in ms: 40.0
# NaiveBayes Mean execution time in ms: 48.75
# RandomForest Median execution time in ms: 60.0
# RandomForest Mean execution time in ms: 55.45454545454545
# SVM Median execution time in ms: 80.0
# SVM Mean execution time in ms: 74.54545454545455
# IBk Median execution time in ms: 20.0
# IBk Mean execution time in ms: 20.0

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

#Create a custom algorithm by setting classifier and name
#---------------------------------------------------
clf =  QuadraticDiscriminantAnalysis()
name = "CustomAlgorithmQuadraticDiscriminantAnalysis"
#---------------------------------------------------
runMLAlgorithm(estimator=clf, name=name, settings=settings)
plot_alg(data, settings.strats, maxBaseline, problemType)

# %%
# %matplotlib nbagg
from scripts.relativePerformance import * 
showRelativePerformanceBoxplot(scores, topList, settings.strats, maxBaseline) 
#Run this cell again to start the interactive plot
# Out:
# <img src="data:image/png;base64,..." width="720">
# <img src="data:image/png;base64,..." width="720">

# %%
# %matplotlib inline

# %% [markdown]
#     # Automatic Jupyter Notebook for OpenML dataset 9: autos

# %%
# %matplotlib inline
from scripts.preamble import *
did = 9
data = oml.datasets.get_dataset(did)
X, y, features = getData(data)
task, topList, strats, scores = getOpenMLData(did, data.default_target_attribute) 
topList[:10]
# Out:
#                                                 flow     score
# 0  weka.kf.AttributeSelection-Ranker-ReliefF-KSta...  0.972876
# 1    weka.RotationForest_PrincipalComponents_J48(14)  0.971229
# 2    weka.RotationForest_PrincipalComponents_J48(14)  0.970180
# 3     weka.RotationForest_PrincipalComponents_J48(3)  0.970180
# 4                                     RandomRules(1)  0.968295
# 5  weka.kf.AttributeSelection-BestFirst-CfsSubset...  0.967469
# 6    weka.RotationForest_PrincipalComponents_J48(14)  0.967256
# 7    weka.RotationForest_PrincipalComponents_J48(14)  0.966511
# 8                                weka.Bagging_J48(2)  0.964775
# 9                                weka.Bagging_J48(1)  0.964775

# %%
from scripts.problemType import *
problemType = findProblemType(data) 
checkTask(task, problemType, data.default_target_attribute)
# Out:
# Problem type: supervised classification problem.
# Using correct task

# %%
from scripts.dataVisualization import *
show1DHist(data)

# %%
from scripts.outlierDetection import *
outlierDetection(X, features, 10)
# Out:
# <style  type="text/css" >
#     #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow0_col2 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow0_col4 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow0_col6 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow0_col7 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow0_col13 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow0_col16 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow0_col25 {
#             background-color:  #ff0000;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow1_col2 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow1_col4 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow1_col6 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow1_col7 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow1_col13 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow1_col16 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow1_col25 {
#             background-color:  #ff6e6e;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow2_col3 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow2_col4 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow2_col6 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow2_col7 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow2_col25 {
#             background-color:  #ff8888;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow3_col2 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow3_col4 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow3_col5 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow3_col7 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow3_col25 {
#             background-color:  #ff8888;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow4_col2 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow4_col6 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow4_col7 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow4_col13 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow4_col16 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow4_col25 {
#             background-color:  #ffa0a0;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow5_col2 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow5_col4 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow5_col5 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow5_col6 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow5_col7 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow5_col16 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow5_col25 {
#             background-color:  #ffa7a7;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow6_col3 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow6_col6 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow6_col7 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow6_col25 {
#             background-color:  #ffc6c6;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow7_col2 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow7_col6 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow7_col7 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow7_col12 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow7_col16 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow7_col18 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow7_col25 {
#             background-color:  #ffd2d2;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow8_col2 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow8_col6 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow8_col7 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow8_col12 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow8_col16 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow8_col18 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow8_col25 {
#             background-color:  #ffd3d3;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow9_col3 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow9_col6 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow9_col7 {
#             background-color:  yellow;
#         }    #T_5d104edc_39ce_11e9_b783_6245b4ebbdcfrow9_col25 {
#             background-color:  #ffe5e5;
#         }</style>
# <table id="T_5d104edc_39ce_11e9_b783_6245b4ebbdcf" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >normalized-losses</th>
#         <th class="col_heading level0 col1" >make</th>
#         <th class="col_heading level0 col2" >fuel-type</th>
#         <th class="col_heading level0 col3" >aspiration</th>
#         <th class="col_heading level0 col4" >num-of-doors</th>
#         <th class="col_heading level0 col5" >body-style</th>
#         <th class="col_heading level0 col6" >drive-wheels</th>
#         <th class="col_heading level0 col7" >engine-location</th>
#         <th class="col_heading level0 col8" >wheel-base</th>
#         <th class="col_heading level0 col9" >length</th>
#         <th class="col_heading level0 col10" >width</th>
#         <th class="col_heading level0 col11" >height</th>
#         <th class="col_heading level0 col12" >curb-weight</th>
#         <th class="col_heading level0 col13" >engine-type</th>
#         <th class="col_heading level0 col14" >num-of-cylinders</th>
#         <th class="col_heading level0 col15" >engine-size</th>
#         <th class="col_heading level0 col16" >fuel-system</th>
#         <th class="col_heading level0 col17" >bore</th>
#         <th class="col_heading level0 col18" >stroke</th>
#         <th class="col_heading level0 col19" >compression-ratio</th>
#         <th class="col_heading level0 col20" >horsepower</th>
#         <th class="col_heading level0 col21" >peak-rpm</th>
#         <th class="col_heading level0 col22" >city-mpg</th>
#         <th class="col_heading level0 col23" >highway-mpg</th>
#         <th class="col_heading level0 col24" >price</th>
#         <th class="col_heading level0 col25" >outlier</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_5d104edc_39ce_11e9_b783_6245b4ebbdcflevel0_row0" class="row_heading

# %%
from scripts.localDataOpenMLInterface import *
showTopNSimilarDatasets("datasetSimilarityMatrixNormalized", did, 10)
# Out:
#     did                       name  similarity                            url
# 0   328                    bridges       0.717   https://www.openml.org/d/328
# 1   171              primary-tumor       0.672   https://www.openml.org/d/171
# 2   372             internet_usage       0.633   https://www.openml.org/d/372
# 3  1459      artificial-characters       0.622  https://www.openml.org/d/1459
# 4    41                      glass       0.620    https://www.openml.org/d/41
# 5   184                      kropt       0.620   https://www.openml.org/d/184
# 6   327                    bridges       0.614   https://www.openml.org/d/327
# 7   382          ipums_la_97-small       0.614   https://www.openml.org/d/382
# 8   133  BNG(glass,nominal,137781)       0.604   https://www.openml.org/d/133
# 9   307                      vowel       0.584   https://www.openml.org/d/307

# %% [markdown]
# Complexity threshold to determine if an algorithm will be run.

# %%
comp = 50000000000000

# %%
from scripts.featureImportance import *
featureImportance(data)

# %%
from scripts.baselines import *
maxBaseline = generateBaselines(data, problemType)

# %% [markdown]
# Please run the full notebook then toggle removeOutliers and run this cell and the next to compare the algorithms with and without outliers.

# %%
removeOutliers = False

# %%
from scripts.relativePerformance import * 
showRelativePerformanceBoxplot(scores, topList, strats, maxBaseline)

# %%
from scripts.machineLearningAlgorithms import *
settings = runMachineLearningAlgorithms(data, comp, strats, problemType, task, showRuntimePrediction=False, runTPOT=False, removeOutliers=removeOutliers)
plot_alg(data, settings.strats, maxBaseline, problemType)
# Out:
# c:\users\hugo\anaconda3\lib\site-packages\deap\tools\_hypervolume\pyhv.py:33: ImportWarning: Falling back to the python version of hypervolume module. Expect this to be very slow.
#   "module. Expect this to be very slow.", ImportWarning)
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 0: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 1: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 2: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 3: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 4: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 5: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 6: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 7: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 8: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 9: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# Run already exists in OpenML, WIP
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 0: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 1: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 2: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 3: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 4: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 5: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 6: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 7: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 8: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 9: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 0: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 1: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 2: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 3: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 4: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 5: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 6: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 7: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 8: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# c:\users\hugo\anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py:544: UserWarning: Repeat 0 Fold 9: estimator only predicted for 6/7 classes!
#   warnings.warn("Repeat %d Fold %d: estimator only predicted for %d/%d classes!" % (rep_no, fold_no, ProbaY.shape[1], len(task.class_labels)))
# Run already exists in OpenML, WIP

# %%
clf = 
runMLAlgorithm(estimator=clf, name="CustomAlgorithm", settings=settings)
plot_alg(data, settings.strats, maxBaseline, problemType)

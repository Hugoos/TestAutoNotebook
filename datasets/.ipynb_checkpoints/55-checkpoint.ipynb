# %% [markdown]
#     # Automatic Jupyter Notebook for OpenML dataset 55: hepatitis

# %%
from scripts.preamble import *
did = 55
data = oml.datasets.get_dataset(did)
tasks = getDatasetTasks(did) 
topRun = getTopRun(tasks)
scores = []
for id, _ in topRun.items():
    run = runs.get_run(id)
    scores.append({"flow":run.flow_name,
                  "score": run.evaluations['are_under_roc']})
# Out:
# {6145: {'run_id': 6145, 'task_id': 54, 'flow_id': 65, 'uploader': 2, 'setup_id': 10}, 131074: {'run_id': 131074, 'task_id': 54, 'flow_id': 419, 'uploader': 2, 'setup_id': 666}, 559109: {'run_id': 559109, 'task_id': 54, 'flow_id': 3478, 'uploader': 939, 'setup_id': 5788}, 22536: {'run_id': 22536, 'task_id': 54, 'flow_id': 344, 'uploader': 2, 'setup_id': 567}, 399020: {'run_id': 399020, 'task_id': 54, 'flow_id': 1200, 'uploader': 2, 'setup_id': 2070}, 14348: {'run_id': 14348, 'task_id': 54, 'flow_id': 66, 'uploader': 2, 'setup_id': 71}, 485378: {'run_id': 485378, 'task_id': 54, 'flow_id': 1154, 'uploader': 603, 'setup_id': 1913}, 8867854: {'run_id': 8867854, 'task_id': 54, 'flow_id': 7781, 'uploader': 710, 'setup_id': 6833247}, 444435: {'run_id': 444435, 'task_id': 54, 'flow_id': 1185, 'uploader': 2, 'setup_id': 2032}, 8216: {'run_id': 8216, 'task_id': 54, 'flow_id': 60, 'uploader': 2, 'setup_id': 99}, 8219: {'run_id': 8219, 'task_id': 54, 'flow_id': 70, 'uploader': 2, 'setup_id': 150}, 448540: {'run_id': 448540, 'task_id': 54, 'flow_id': 1168, 'uploader': 2, 'setup_id': 1921}, 163870: {'run_id': 163870, 'task_id': 54, 'flow_id': 482, 'uploader': 2, 'setup_id': 967}, 145755: {'run_id': 145755, 'task_id': 54, 'flow_id': 398, 'uploader': 2, 'setup_id': 611}, 557092: {'run_id': 557092, 'task_id': 54, 'flow_id': 3466, 'uploader': 939, 'setup_id': 5777}, 347142: {'run_id': 347142, 'task_id': 54, 'flow_id': 1172, 'uploader': 2, 'setup_id': 1924}, 10282: {'run_id': 10282, 'task_id': 54, 'flow_id': 57, 'uploader': 2, 'setup_id': 120}, 290861: {'run_id': 290861, 'task_id': 54, 'flow_id': 1108, 'uploader': 2, 'setup_id': 1877}, 37213: {'run_id': 37213, 'task_id': 54, 'flow_id': 611, 'uploader': 2, 'setup_id': 1035}, 505906: {'run_id': 505906, 'task_id': 54, 'flow_id': 1721, 'uploader': 603, 'setup_id': 2364}, 196661: {'run_id': 196661, 'task_id': 54, 'flow_id': 1179, 'uploader': 1, 'setup_id': 2021}, 22584: {'run_id': 22584, 'task_id': 54, 'flow_id': 205, 'uploader': 2, 'setup_id': 337}, 11957: {'run_id': 11957, 'task_id': 54, 'flow_id': 66, 'uploader': 2, 'setup_id': 70}, 251969: {'run_id': 251969, 'task_id': 54, 'flow_id': 1163, 'uploader': 2, 'setup_id': 1917}, 467012: {'run_id': 467012, 'task_id': 54, 'flow_id': 1185, 'uploader': 2, 'setup_id': 2032}, 69: {'run_id': 69, 'task_id': 54, 'flow_id': 75, 'uploader': 1, 'setup_id': 16}, 352327: {'run_id': 352327, 'task_id': 54, 'flow_id': 1165, 'uploader': 2, 'setup_id': 1918}, 272457: {'run_id': 272457, 'task_id': 54, 'flow_id': 1244, 'uploader': 2, 'setup_id': 2166}, 14411: {'run_id': 14411, 'task_id': 54, 'flow_id': 60, 'uploader': 2, 'setup_id': 95}, 415822: {'run_id': 415822, 'task_id': 54, 'flow_id': 1192, 'uploader': 2, 'setup_id': 2046}, 38991: {'run_id': 38991, 'task_id': 54, 'flow_id': 611, 'uploader': 2, 'setup_id': 1036}, 38992: {'run_id': 38992, 'task_id': 54, 'flow_id': 611, 'uploader': 2, 'setup_id': 1036}, 8274: {'run_id': 8274, 'task_id': 54, 'flow_id': 72, 'uploader': 2, 'setup_id': 138}, 114772: {'run_id': 114772, 'task_id': 54, 'flow_id': 406, 'uploader': 2, 'setup_id': 632}, 168021: {'run_id': 168021, 'task_id': 54, 'flow_id': 598, 'uploader': 2, 'setup_id': 972}, 270424: {'run_id': 270424, 'task_id': 54, 'flow_id': 1091, 'uploader': 2, 'setup_id': 1861}, 92249: {'run_id': 92249, 'task_id': 54, 'flow_id': 675, 'uploader': 2, 'setup_id': 1216}, 92250: {'run_id': 92250, 'task_id': 54, 'flow_id': 675, 'uploader': 2, 'setup_id': 1216}, 10332: {'run_id': 10332, 'task_id': 54, 'flow_id': 151, 'uploader': 2, 'setup_id': 183}, 551005: {'run_id': 551005, 'task_id': 54, 'flow_id': 3418, 'uploader': 939, 'setup_id': 5616}, 12382: {'run_id': 12382, 'task_id': 54, 'flow_id': 139, 'uploader': 2, 'setup_id': 57}, 97: {'run_id': 97, 'task_id': 54, 'flow_id': 60, 'uploader': 1, 'setup_id': 5}, 204900: {'run_id': 204900, 'task_id': 54, 'flow_id': 1182, 'uploader': 2, 'setup_id': 2027}, 24678: {'run_id': 24678, 'task_id': 54, 'flow_id': 155, 'uploader': 2, 'setup_id': 198}, 135272: {'run_ ...

# %%
from scripts.problemType import *
problemType = findProblemType(data)
# Out:
# Problem type: classification problem.

# %% [markdown]
# Complexity threshold to determine if an algorithm will be run.

# %%
comp = 50000000000000

# %%
from scripts.featureImportance import *
featureImportance(data)

# %%
from scripts.baselines import *
maxBaseline = generateBaselines(data, problemType)

# %%
from scripts.machineLearningAlgorithms import *
strats = {}
strats = runMachineLearningAlgorithms(data, comp, strats, problemType)
plot_alg(data, strats, maxBaseline, problemType)

# %%
from scripts.preamble import *
did = 55
data = oml.datasets.get_dataset(did)
task, topList, strats = printTopNFlows(did, data.default_target_attribute, 10)
# Out:
# C:\Users\Hugo\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
from scripts.problemType import *
problemType = findProblemType(data)
# Out:
# Problem type: supervised classification problem.

# %%
comp = 50000000000000

# %%
from scripts.machineLearningAlgorithms import *
strats = runMachineLearningAlgorithms(data, comp, strats, problemType, task, showRuntimePrediction=True, runTPOT=False)
plot_alg(data, strats, maxBaseline, problemType)
# Out:
# C:\Users\Hugo\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\Hugo\Anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# C:\Users\Hugo\Anaconda3\lib\site-packages\sklearn\learning_curve.py:22: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)
# Median execution time in ms: 0.0
# Mean execution time in ms: 138.52941176470588
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-3886e6483bb2> in <module>()
#       1 from scripts.machineLearningAlgorithms import *
# ----> 2 strats = runMachineLearningAlgorithms(data, comp, strats, problemType, task, showRuntimePrediction=True, runTPOT=False)
#       3 plot_alg(data, strats, maxBaseline, problemType)
#
# H:\MasterThesis\auto-jupyter-notebook-master\datasets\scripts\machineLearningAlgorithms.py in runMachineLearningAlgorithms(data, comp, strats, problemType, task, showRuntimePrediction, runTPOT, timeLimit)
#      40     if problemType == CLASSIFICATION:
#      41         strats = runMLAlgorithm(tree.DecisionTreeClassifier(criterion="gini", max_depth=None, min_samples_leaf=1, max_features=None, max_leaf_nodes=None),
# ---> 42                                 "decision tree", strats, task, showRuntimePrediction, "J48", timeLimit, isTooLong(n**2 * p, comp))
#      43         strats = runMLAlgorithm(MultinomialNB(alpha=1.0),
#      44                                 "naive bayes", strats, task, showRuntimePrediction, "NaiveBayes", timeLimit, isTooLong(n * p, comp))
#
# H:\MasterThesis\auto-jupyter-notebook-master\datasets\scripts\machineLearningAlgorithms.py in runMLAlgorithm(clf, name, strats, task, showRuntimePrediction, RTPName, timeLimit, tooLong)
#     167         flow = flows.sklearn_to_flow(clf)
#     168         try:
# --> 169             run = runs.run_flow_on_task(taskId, flow, avoid_duplicate_runs = True)
#     170         except PyOpenMLError:
#     171             print("Run already exists in OpenML, WIP")
#
# ~\Anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py in run_flow_on_task(task, flow, avoid_duplicate_runs, flow_tags, seed)
#     101
#     102     # execute the run
# --> 103     res = _run_task_get_arffcontent(flow.model, task)
#     104
#     105     # in case the flow not exists, we will get a "False" back (which can be
#
# ~\Anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py in _run_task_get_arffcontent(model, task)
#     405             for sample_no in range(num_samples):
#     406                 model_fold = sklearn.base.clone(model, safe=True)
# --> 407                 res =_run_model_on_fold(model_fold, task, rep_no, fold_no, sample_no, can_measure_runtime)
#     408                 arff_datacontent_fold, arff_tracecontent_fold, user_defined_measures_fold, model_fold = res
#     409
#
# ~\Anaconda3\lib\site-packages\openml-0.7.0-py3.5.egg\openml\runs\functions.py in _run_model_on_fold(model, task, rep_no, fold_no, sample_no, can_measure_runtime)
#     499         if can_measure_runtime:
#     500             modelfit_starttime = time.process_time()
# --> 501         model.fit(trainX, trainY)
#     502
#     503         if can_measure_runtime:
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
#     118             if issparse(X):
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
